# %% [markdown]
# #<b>TUGAS DATA VISUALIZATION SLO<b>
#
#
# Nama  : Muhammad Surya Sanjiwani
#
# NIM   : 1101200113

# %% [markdown]
# ### **PRE-PROCESSING**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.figure_factory as ff
import plotly.graph_objects as go
import numpy as np
import plotly.express as px

# %%
path = "/content/drive/MyDrive/TUGAS SLO/epl-goalScorer(20-21).csv"
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
# 3           3   453    Son Heung-Min     37  3139     17  11.023287       10
# 4           4   822  Patrick Bamford     38  3085     17  18.401863        7
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
# 3   9.512992     68          75             0          0    F M S
# 4   3.782247    107          30             3          0      F S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# ...

# %%
print(data.dtypes)
# Out:
# Unnamed: 0        int64
# id                int64
# player_name      object
# games             int64
# time              int64
# goals             int64
# xG              float64
# assists           int64
# xA              float64
# shots             int64
# key_passes        int64
# yellow_cards      int64
# red_cards         int64
# position         object
# team_title       object
# npg               int64
# npxG            float64
# xGChain         float64
# xGBuildup       float64
# dtype: object

# %%
data_no_id = data.iloc[:,2:]
data_no_id
# Out:
#                 player_name  games  time  goals         xG  assists  \
# 0                Harry Kane     35  3097     23  22.174859       14
# 1             Mohamed Salah     37  3085     22  20.250847        5
# 2           Bruno Fernandes     37  3117     18  16.019454       12
# 3             Son Heung-Min     37  3139     17  11.023287       10
# 4           Patrick Bamford     38  3085     17  18.401863        7
# ..                      ...    ...   ...    ...        ...      ...
# 517  Jaden Philogene-Bidace      1     1      0   0.000000        0
# 518         Gaetano Berardi      2   113      0   0.074761        0
# 519          Anthony Elanga      1    67      0   0.000000        0
# 520             Femi Seriki      1     1      0   0.000000        0
# 521         Tyrese Francois      1    13      0   0.000000        0
#
#             xA  shots  key_passes  yellow_cards  red_cards position  \
# 0     7.577094    138          49             1          0        F
# ...

# %% [markdown]
# ### **10 PLAYER PENCETAK GOL TERBANYAK**

# %%
top_10_goals = data_no_id.nlargest(10, 'goals')

# Creating the bar chart
fig_bar = px.bar(data_frame=top_10_goals,
                 x='player_name', y='goals', color='goals', text='goals',
                 labels={'player_name': 'Player Name', 'goals': 'Goals'})

# Updating bar properties
fig_bar.update_traces(marker=dict(line=dict(color='#000000', width=1)),
                      texttemplate='%{text:.2s}', textposition='outside')

# Updating layout
fig_bar.update_layout(title_text='Top 10 Goal Kings of the League',  # Main title for the project
                      title_x=0.5, title_font=dict(size=30))  # Location and the font size of the main title

# Showing the plot
fig_bar.show()

print(top_10_goals[['player_name', 'goals']])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **10 PLAYER TERLAMA DURASI BERMAIN**

# %%
top_10_time = data_no_id.nlargest(10, 'time')

# Creating the bar chart
fig_bar = px.bar(data_frame=top_10_time,
                 x='player_name', y='time', color='time', text='time',
                 labels={'player_name': 'Player Name', 'time': 'Time'})

# Updating bar properties
fig_bar.update_traces(marker=dict(line=dict(color='#000000', width=1)),
                      texttemplate='%{text:.2s}', textposition='outside')

# Updating layout
fig_bar.update_layout(title_text='Top 10 Time Played',  # Main title for the project
                      title_x=0.5, title_font=dict(size=30))  # Location and the font size of the main title

# Showing the plot
fig_bar.show()

print(top_10_time[['player_name', 'time']])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **10 PLAYER ASSIST TERBANYAK**

# %%
top_10_assists = data_no_id.nlargest(10, 'assists')

# Creating the bar chart
fig_bar = px.bar(data_frame=top_10_assists,
                 x='player_name', y='assists', color='assists', text='assists',
                 labels={'player_name': 'Player Name', 'assists': 'Assist'})

# Updating bar properties
fig_bar.update_traces(marker=dict(line=dict(color='#000000', width=1)),
                      texttemplate='%{text:.2s}', textposition='outside')

# Updating layout
fig_bar.update_layout(title_text='Top 10 Assists',  # Main title for the project
                      title_x=0.5, title_font=dict(size=30))  # Location and the font size of the main title

# Showing the plot
fig_bar.show()

print(top_10_assists[['player_name', 'assists']])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **4 PLAYER PENCETAK GOL TERBANYAK DARI MAN CITY**

# %%
# Filter the dataset to include only players from Manchester City
man_city_players = data[data['team_title'] == 'Manchester City']

# Select the top 4 goal scorers from Manchester City
top_4_man_city_scorers = man_city_players.nlargest(4, 'goals')

# Create the bar chart for the top 4 goal scorers from Manchester City
fig_bar_man_city = px.bar(data_frame=top_4_man_city_scorers,
                          x='player_name', y='goals', color='goals', text='goals',
                          labels={'player_name': 'Player Name', 'goals': 'Goals'})

# Update bar properties
fig_bar_man_city.update_traces(marker=dict(line=dict(color='#000000', width=1)),
                                texttemplate='%{text:.2s}', textposition='outside')

# Update layout
fig_bar_man_city.update_layout(title_text='Top 4 Goal Scorers from Manchester City',  # Main title for the project
                               title_x=0.5, title_font=dict(size=30))  # Location and the font size of the main title

# Show the plot
fig_bar_man_city.show()

print(top_4_man_city_scorers[['player_name', 'goals']])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **KESEBELASAN DENGAN GOL TERBANYAK**

# %%
teams_goals = data_no_id.groupby('team_title')['goals'].sum()

teams_sort =teams_goals.sort_values(ascending=False)

team_with_most_goals = teams_sort.index[0]

print("Kesebelasan dengan pencetak gol terbanyak :", team_with_most_goals)
print("Jumlah gol:", teams_goals[team_with_most_goals])
# Out:
# Kesebelasan dengan pencetak gol terbanyak : Manchester City
# Jumlah gol: 77

# %% [markdown]
# ### **JUMLAH KARTU KUNING DAN MERAH PLAYER ASSIST TERBANYAK**

# %%
top_1_assists_player = data.nlargest(1, 'assists')

top_assist_name = top_1_assists_player['player_name'].iloc[0]
top_assist_rc = top_1_assists_player['yellow_cards'].iloc[0]
top_assist_yc = top_1_assists_player['red_cards'].iloc[0]

print("Jumlah Kartu Kuning dan Merah dari Player dengan Assist Terbanyak:", top_assist_name)
print("Kartu kuning:", top_assist_yc)
print("Kartu merah:", top_assist_rc)
# Out:
# Jumlah Kartu Kuning dan Merah dari Player dengan Assist Terbanyak: Harry Kane
# Kartu kuning: 0
# Kartu merah: 1

# %% [markdown]
# ### **KESEBELASAN DENGAN PLAYER ASSIST DAN GOL TERBANYAK**

# %%
# Find the player with the most assists and goals overall
top_assist_player = data.nlargest(1, 'assists')
top_goal_player = data.nlargest(1, 'goals')

# Extract the team titles of the top assist and goal scorers
top_assist_team = top_assist_player['team_title'].iloc[0]
top_goal_team = top_goal_player['team_title'].iloc[0]

# Print the top team with the player who has the most assists and goals
print("Kesebelasan dengan player assis Assists:")
print("Team:", top_assist_team)
print("Player:", top_assist_player['player_name'].iloc[0])
print("Assists:", top_assist_player['assists'].iloc[0])

print("\nTop Team with Player with Most Goals:")
print("Team:", top_goal_team)
print("Player:", top_goal_player['player_name'].iloc[0])
print("Goals:", top_goal_player['goals'].iloc[0])
# Out:
# Top Team with Player with Most Assists:
# Team: Tottenham
# Player: Harry Kane
# Assists: 14
#
# Top Team with Player with Most Goals:
# Team: Tottenham
# Player: Harry Kane
# Goals: 23

# %% [markdown]
# ### **TOP 5 KESEBELASAN DENGAN GOL TERBANYAK**

# %%
goalsbyteam = data.groupby('team_title')['goals'].sum().nlargest(5).to_frame().reset_index()

fig = px.bar(data_frame=goalsbyteam, x='team_title', y='goals', color='goals')

fig.update_layout(title_text='Top 5 Teams with the Most Goals',
                  title_x=0.5, title_font=dict(size=30),
                  xaxis={'categoryorder': 'total descending'})

fig.update_traces(marker=dict(line=dict(color='#000000', width=2)))

fig.show()
print(goalsbyteam)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **URUTAN PLAYER DENGAN GOL TERBANYAK TANPA KARTU**

# %%
filtered_data = data[(data['yellow_cards'] == 0) & (data['red_cards'] == 0)]

top_scorer = filtered_data.nlargest(10, 'goals')

fig_bar = px.bar(data_frame=top_scorer, x='player_name', y='goals', color='goals')

fig_bar.update_traces(marker=dict(line=dict(color='#000000', width=2)), texttemplate='%{y}')

fig_bar.update_layout(title_text='Top Scorer without Red or Yellow Cards',
                      title_x=0.5, title_font=dict(size=30),
                      xaxis_title='Player Name',
                      yaxis_title='Goals')

fig_bar.show()

print(top_scorer[["player_name","goals"]])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
